# %% [markdown]
# # 서울특별시 행정동별 친환경자동차 현황-제원번호 포함 자료(2022.2.28)

# %%
import pandas as pd

# %%
hjDF=pd.read_csv('./서울특별시 행정동별 친환경자동차 현황-제원번호 포함 자료(2022.2.28).CSV', encoding='cp949')

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
# ...

# %%
hjDF['최초등록일'].
# Out:
# dtype('int64')

# %%
hjDF['최초등록일_날짜'] = pd.to_datetime(hjDF['최초등록일'])

# %%
hjDF=hjDF.drop(['최초등록일_날짜'], axis=1)

# %%
hjDF['최초등록일'].astype('str')
# Out:
# 0         20200910
# 1         20170710
# 2         20210309
# 3         20210528
# 4         20200630
#             ...
# 189581    20180824
# 189582    20150212
# 189583    20180109
# 189584    20210315
# 189585    20120105
# Name: 최초등록일, Length: 189586, dtype: object

# %%
hjDF['최초등록일_날짜'] = pd.to_datetime(hjDF['최초등록일'])

# %%
hjDF=hjDF.drop(['최초등록일_날짜'], axis=1)

# %%
hjDF['최초등록일']=hjDF['최초등록일'].astype('str')

# %%
hjDF['최초등록일'].dtype
# Out:
# dtype('O')

# %%
hjDF['최초등록일_년도']=hjDF['최초등록일'].str[:4]

# %%
vcDF=pd.DataFrame(hjDF['최초등록일_년도'].value_counts())

# %%
vcDF_2=vcDF.reset_index()

# %%
vcDF_2.columns=['year', 'counts']

# %%
vcDF_2.to_csv('년도별_valuecounts.csv', index=False)

# %%
hjDF.isna().sum()
# Out:
# 기준년월                   0
# 사용본거지시읍면동_행정동기준       11
# 차명                     0
# 연료                     0
# 최초등록일                  0
# 현소유자의출생년도          44764
# 제원관리번호                 0
# 최초등록일_년도               0
# dtype: int64

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
# ...

# %%
hjDF.dropna(subset = ['사용본거지시읍면동_행정동기준'])

# %%
import numpy as np

# %%
hjDF['사용본거지시읍면동_행정동기준'].unique()
# Out:
# array(['서울특별시 강남구 개포1동', '서울특별시 강남구 개포2동', '서울특별시 강남구 개포4동',
#        '서울특별시 강남구 논현1동', '서울특별시 강남구 논현2동', '서울특별시 강남구 대치1동',
#        '서울특별시 동작구 상도1동', '서울특별시 동작구 상도2동', '서울특별시 동작구 상도3동',
#        '서울특별시 동작구 상도4동', '서울특별시 동작구 신대방1동', '서울특별시 동작구 신대방2동',
#        '서울특별시 동작구 흑석동', '서울특별시 마포구 공덕동', '서울특별시 강남구 대치2동',
#        '서울특별시 마포구 대흥동', '서울특별시 마포구 도화동', '서울특별시 마포구 망원1동',
#        '서울특별시 마포구 망원2동', '서울특별시 마포구 상암동', '서울특별시 마포구 서강동',
#        '서울특별시 강남구 대치4동', '서울특별시 마포구 서교동', '서울특별시 마포구 성산1동',
#        '서울특별시 마포구 성산2동', '서울특별시 마포구 신수동', '서울특별시 마포구 아현동',
#        '서울특별시 강남구 도곡1동', '서울특별시 마포구 연남동', '서울특별시 마포구 염리동',
#        '서울특별시 마포구 용강동', '서울특별시 강남구 도곡2동', '서울특별시 마포구 합정동',
#        '서울특별시 서대문구 남가좌1동', '서울특별시 강남구 삼성1동', '서울특별시 서대문구 남가좌2동',
#        '서울특별시 강남구 삼성2동', '서울특별시 서대문구 북가좌1동', '서울특별시 서대문구 북가좌2동',
#        '서울특별시 강남구 세곡동', '서울특별시 서대문구 북아현동', '서울특별시 서대문구 신촌동',
#        '서울특별시 서대문구 연희동', '서울특별시 서대문구 천연동', '서울특별시 강남구 수서동',
# ...

# %%
hjDF['사용본거지시읍면동_행정동기준'].isna().sum()
# Out:
# 11

# %%
hjDF_2=hjDF.copy()

# %%
hjDF

# %%
hjDF_2['사용본거지시읍면동_행정동기준']
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
# ...

# %%
hjDF['사용본거지시읍면동_행정동기준'].dropna().isna().sum()
# Out:
# 0

# %%
hjDF[hjDF['사용본거지시읍면동_행정동기준']==nan]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [203], in <cell line: 1>()
# ----> 1 hjDF[hjDF['사용본거지시읍면동_행정동기준']==nan]
#
# NameError: name 'nan' is not defined

# %%
hjDF_2['사용본거지시읍면동_행정동기준']=hjDF['사용본거지시읍면동_행정동기준'].dropna()

# %%
hjDF_2['사용본거지시읍면동_행정동기준'].isna().sum()
# Out:
# 11

# %%
hjDF_2['사용본거지시읍면동_행정동기준']
# Out:
# 0         서울특별시 강남구 개포1동
# 1         서울특별시 강남구 개포1동
# 2         서울특별시 강남구 개포1동
# 3         서울특별시 강남구 개포1동
# 4         서울특별시 강남구 개포1동
#                ...
# 189581    서울특별시 중랑구 중화2동
# 189582    서울특별시 중랑구 중화2동
# 189583    서울특별시 중랑구 중화2동
# 189584    서울특별시 중랑구 중화2동
# 189585               NaN
# Name: 사용본거지시읍면동_행정동기준, Length: 189586, dtype: object

# %%
hjDF.dropna(subset = ['사용본거지시읍면동_행정동기준'])
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189580  202202  서울특별시 중랑구 중화2동             쏘렌토 하이브리드  하이브리드(휘발유+전기)  20210517
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
#
# ...

# %%
hjDF_3=hjDF.dropna(subset = ['사용본거지시읍면동_행정동기준'])

# %%
hjDF_3.isna().sum()
# Out:
# 기준년월                   0
# 사용본거지시읍면동_행정동기준        0
# 차명                     0
# 연료                     0
# 최초등록일                  0
# 현소유자의출생년도          44753
# 제원관리번호                 0
# 최초등록일_년도               0
# dtype: int64

# %%
hjDF_3.to_csv('(행정동 결측치 제거)서울특별시 행정동별 친환경자동차 현황-제원번호 포함 자료(2022.2.28).csv', index=False)

# %% [markdown]
# # 한국전력공사_서울시 전기차 충전소 충전량_20220331

# %%
chargingDF=pd.read_csv('./한국전력공사_서울시 전기차 충전소 충전량_20220331.CSV', encoding='cp949')

# %%
chargingDF.isna().sum()
# Out:
# 충전구분           0
# 충전소명           0
# 주소          1488
# 충전기용량     104677
# 충전량       103510
# 충전시간      103510
# 충전분       103510
# 충전시작시각    103510
# 충전종료시각    103510
# dtype: int64

# %%
chargingDF[['충전구분', '충전소명', '주소']]
# Out:
#        충전구분     충전소명                  주소
# 0        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 1        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 2        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 3        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 4        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# ...     ...      ...                 ...
# 638697   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638698   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638699   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638700   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638701   급속  서울전력관리처    서울특별시 중구 퇴계로 140
#
# [638702 rows x 3 columns]

# %%
chargingDF[['충전구분', '충전소명', '주소']].isna().sum()
# Out:
# 충전구분       0
# 충전소명       0
# 주소      1488
# dtype: int64

# %%
chargingDF_2=chargingDF[['충전구분', '충전소명', '주소']]

# %%
chargingDF_2 =chargingDF_2[chargingDF_2.duplicated() ==False].reset_index(drop = True)

# %%
chargingDF_2[chargingDF_2.isna().sum(1)>0]
# Out:
#     충전구분        충전소명   주소
# 152   급속  여의도KBS (본관  NaN
# 477   완속       면목두산2  NaN
# 485   완속       면목두산4  NaN
# 488   급속       면목두산4  NaN
# 516   급속       면목두산2  NaN

# %%
#chargingDF_2[chargingDF_2.isna().sum(1)>0]['주소'][152].fillna('서울 영등포구 여의공원로 13')

# %%
# 조건식으로 찾아서 대체?
chargingDF_2['주소'][152]='서울 영등포구 여의공원로 13'

# %%
chargingDF_2['주소'][152]
# Out:
# '서울 영등포구 여의공원로 13'

# %%
chargingDF_2[chargingDF_2.isna().sum(1)>0]
# Out:
#     충전구분   충전소명   주소
# 477   완속  면목두산2  NaN
# 485   완속  면목두산4  NaN
# 488   급속  면목두산4  NaN
# 516   급속  면목두산2  NaN

# %%
chargingDF_2['주소'][477]='서울시 중랑구 면목로37길 58'

# %%
chargingDF_2['주소'][516]='서울시 중랑구 면목로37길 58'

# %%
chargingDF_2['주소'][485]='서울시 중랑구 면목로35길 63'

# %%
chargingDF_2['주소'][488]='서울시 중랑구 면목로35길 63'

# %%
chargingDF_2.iloc[[152, 477, 485, 488, 516]]
# Out:
#     충전구분        충전소명                 주소
# 152   급속  여의도KBS (본관   서울 영등포구 여의공원로 13
# 477   완속       면목두산2  서울시 중랑구 면목로37길 58
# 485   완속       면목두산4  서울시 중랑구 면목로35길 63
# 488   급속       면목두산4  서울시 중랑구 면목로35길 63
# 516   급속       면목두산2  서울시 중랑구 면목로37길 58

# %%
chargingDF_2.isna().sum()
# Out:
# 충전구분    0
# 충전소명    0
# 주소      0
# dtype: int64

# %%
chargingDF_2.isnull().sum()
# Out:
# 충전구분    0
# 충전소명    0
# 주소      0
# dtype: int64

# %%
# 파일생성
chargingDF_2.to_csv('구분_명_주소.csv', index=False)

# %%
# [add for add in chargingDF_2['주소'].str.split('(')]

# %%
chargingDF['주소'].str.contains('[(]')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 638697    False
# 638698    False
# 638699    False
# 638700    False
# 638701    False
# Name: 주소, Length: 638702, dtype: object

# %% [markdown]
# # 한국전력공사_전기차충전소위경도_20220718

# %%
locDF=pd.read_csv('./한국전력공사_전기차충전소위경도_20220718.CSV', encoding='utf-8')

# %%
seoul_locDF=locDF[locDF['시도']=='서울특별시']

# %%
seoul_locDF.isna().sum()
# Out:
# 시도      0
# 충전소명    0
# 경도      0
# 위도      0
# dtype: int64

# %%
seoul_locDF_dr=seoul_locDF.drop(['시도'], axis=1)
seoul_locDF_dr
# Out:
#                     충전소명         경도          위도
# 1940  공무원연금공단 서울지부(상록회관)  37.504100  127.042944
# 1941             래미안강남힐즈  37.472656  127.095806
# 1942       대치2문화센터 공영주차장  37.502333  127.064214
# 1943           LH강남힐스테이트  37.471028  127.088781
# 1944           세곡푸르지오아파트  37.467354  127.093428
# ...                  ...        ...         ...
# 3813   서울대학교병원 대한외래병동주차장  37.578791  126.997563
# 3814           서울역(한화역사)  37.554656  126.971523
# 3815            약수동공영주차장  37.552157  127.013147
# 3816              중부전력지사  37.543938  126.919917
# 4775               인재개발원  37.635199  127.087363
#
# [631 rows x 3 columns]

# %%
seoul_locDF_dr
# Out:
#                     충전소명         경도          위도
# 1940  공무원연금공단 서울지부(상록회관)  37.504100  127.042944
# 1941             래미안강남힐즈  37.472656  127.095806
# 1942       대치2문화센터 공영주차장  37.502333  127.064214
# 1943           LH강남힐스테이트  37.471028  127.088781
# 1944           세곡푸르지오아파트  37.467354  127.093428
# ...                  ...        ...         ...
# 3813   서울대학교병원 대한외래병동주차장  37.578791  126.997563
# 3814           서울역(한화역사)  37.554656  126.971523
# 3815            약수동공영주차장  37.552157  127.013147
# 3816              중부전력지사  37.543938  126.919917
# 4775               인재개발원  37.635199  127.087363
#
# [631 rows x 3 columns]

# %%
seoul_locDF_dr_2=seoul_locDF_dr.reset_index(drop=True)

# %%
seoul_locDF_dr_2
# Out:
#                    충전소명         경도          위도
# 0    공무원연금공단 서울지부(상록회관)  37.504100  127.042944
# 1               래미안강남힐즈  37.472656  127.095806
# 2         대치2문화센터 공영주차장  37.502333  127.064214
# 3             LH강남힐스테이트  37.471028  127.088781
# 4             세곡푸르지오아파트  37.467354  127.093428
# ..                  ...        ...         ...
# 626   서울대학교병원 대한외래병동주차장  37.578791  126.997563
# 627           서울역(한화역사)  37.554656  126.971523
# 628            약수동공영주차장  37.552157  127.013147
# 629              중부전력지사  37.543938  126.919917
# 630               인재개발원  37.635199  127.087363
#
# [631 rows x 3 columns]

# %%
seoul_locDF_dr_2.to_csv('seoul_loc.csv', index=False)
